# %% [markdown]
# # Agent Evaluation Pipeline
#
# This notebook will run the evaluation pipeline step by step.
#
# Planned sections:
# 1. Setup and imports
# 2. Load input data
# 3. Semantic similarity evaluation
# 4. Gemini-as-judge evaluation
# 5. Optional claim-based comparison
# 6. Summary tables and outputs
